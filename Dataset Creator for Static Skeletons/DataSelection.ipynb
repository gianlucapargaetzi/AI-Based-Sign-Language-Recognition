# %%
import numpy as np
import tensorflow as tk
import matplotlib.pyplot as plt
import os
import cv2

import mediapipe as mp
import shutil
import csv
            
import tkinter as tk
from tkinter import filedialog

# %%
mp_drawing = mp.solutions.drawing_utils
mp_drawing_styles = mp.solutions.drawing_styles
mp_hands = mp.solutions.hands

"""
    List of classes (e.g. 'A' or 'C') in dataset directory
"""
def getClasses(file_path):
    classes = []
    for file in os.listdir(file_path):
        if os.path.isdir(file_path + '/' + file):
            classes.append(file)
    return classes


"""
    List of image files in path
"""
def getImageFiles(path):
    image_files = []
    for file in os.listdir(path):
        if (file.endswith('.png') or file.endswith('.jpg')):
            image_files.append(file)  
    return image_files


"""
    This function copies every file that was selected to the output to insert it in the dataset
    sel_files: List of files which were selected to be copied to the output path
    folder: Class (e.g 'A' or 'C')
    in_path: Path were images are stored (e.g. 'Dataset1/A/')
    out_path: Out Path (e.g. 'Output/Dataset1/')
    anootated_img: create imgs with drawn skeleton?

    copy_img: copy images to destination directory?
"""
def saveDataset(sel_files, folder, in_path, out_path, annotate_img=True, copy_img=True):
    if not os.path.exists(out_path + '/' + folder.upper()):
        os.mkdir(out_path + '/' + folder.upper())
    with mp_hands.Hands(
            static_image_mode=True,
            max_num_hands=1,
            min_detection_confidence=0.85) as hands:

        # Go through each picture of class
        for idx, file in enumerate(sel_files):

            ########################################################################################################
            # Preprocessing
            ########################################################################################################

            # flip input image so that a picture of a right hand is detected as a right hand 
            image = cv2.flip(cv2.imread(in_path + '/' + file),1)
            annotated_image = image.copy()
            # annotated_image is the ouput image with the drawn skeleton in it
            # cv2 reads image in BGR, image has to be converted to RGB (first tests brought conclusion that hand isn't detected in BGR spektrum)
            image = cv2.cvtColor(image,cv2.COLOR_BGR2RGB)

            ########################################################################################################
            # Feature Extraction
            ########################################################################################################

            # apply MediaPipe Hands to the picture
            results = hands.process(image)
            # Print handedness and draw hand landmarks on the image.
            #print('Handedness:', results.multi_handedness)
            if not results.multi_hand_landmarks:
                print(file + ': No hand detected. Discard file!')
                os.remove(in_path + '/' + file)
                continue
            
            if copy_img:
                shutil.copyfile(in_path + '/' + file, out_path + '/' + folder.upper() +'/' + file)
            
            if gen_csv:
                for i in range(21):
                    lm = np.array([hand_landmarks.landmark[i].x,hand_landmarks.landmark[i].y,hand_landmarks.landmark[i].z], dtype=float)
                    coord[i,:] = lm
            if annotate_img:
                if not os.path.exists(out_path + '/Annotated'): 
                    os.mkdir(out_path + '/Annotated')
                if not os.path.exists(out_path + '/Annotated/' + folder.upper()):
                    os.mkdir(out_path + '/Annotated/' + folder.upper())                    
                for hand_landmarks in results.multi_hand_landmarks:
                    # print('hand_landmarks:', hand_landmarks)
                    mp_drawing.draw_landmarks(
                            annotated_image,
                            hand_landmarks,
                            mp_hands.HAND_CONNECTIONS,
                            mp_drawing_styles.get_default_hand_landmarks_style(),
                            mp_drawing_styles.get_default_hand_connections_style())     
                    cv2.imwrite(out_path + '/Annotated/' + folder.upper() + '/' + file, cv2.flip(annotated_image,1))     
        ###########    
        
"""
    This function generates a list of selected files which will be used in the dataset
    If amount of files to be selected (sel_amount) exceeds numer of available files (amount of sel_files), every file is used for dataset
    Elsewise sel_amount files get selected randomly from available files to create dataset
    
    sel_files: List of all files in which a hand was successfully detected
    sel_amount: Amount of files taken from sel_files
"""    
def createDatasetImages(sel_files,sel_amount=30, sel_all=False):
    # Creat class in output folder

    copy_files = []
    
    amount_filtered = len(sel_files)
    
    if (amount_filtered > 0):
        if sel_all:
            copy_files = sel_files
            sel_amount = amount_filtered
        else:
            if sel_amount > amount_filtered:
                copy_files = sel_files
                sel_amount = amount_filtered
                
            for i in range(sel_amount):
                idx = np.random.randint(len(sel_files))
                #print('Copy File ' + SEL_FILES[idx])

                copy_files.append(sel_files[idx])
                del sel_files[idx]        
    return copy_files  


"""
    Create a list of all files in class directory in which a hand is detected
    delete_img: delete non skeletoin images in origin directory?
"""
def scanRawData(image_files, in_path, delete_img=False):
    sel_files = []
    with mp_hands.Hands(
        static_image_mode=True,
        max_num_hands=1,
        min_detection_confidence=0.85) as hands:

        # Go through each picture of class
        #################
        for idx, file in enumerate(image_files):
            # Read an image, flip it around y-axis for correct handedness output (see
            # above).

            ########################################################################################################
            # Preprocessing
            ########################################################################################################

            # flip input image so that a picture of a right hand is detected as a right hand 
            image = cv2.flip(cv2.imread(in_path + '/' +file),1)
            # annotated_image is the ouput image with the drawn skeleton in it
            # cv2 reads image in BGR, image has to be converted to RGB (first tests brought conclusion that hand isn't detected in BGR spektrum)
            image = cv2.cvtColor(image,cv2.COLOR_BGR2RGB)

            ########################################################################################################
            # Feature Extraction
            ########################################################################################################

            # apply MediaPipe Hands to the picture
            results = hands.process(image)
            # Print handedness and draw hand landmarks on the image.
            #print('Handedness:', results.multi_handedness)
            if not results.multi_hand_landmarks or 'depth' in file:
                if delete_img:
                    os.remove(in_path + '/' + file)
                continue
            sel_files.append(file)
        #################
    return sel_files
# Process all directories selected

# %%
root = tk.Tk()
root.withdraw()

IMAGE_FILES = []
SEL_FILES = []
CLASSES = []

#ALL = 1000
#SEL_ALL = False


ANNOTATE = False
COPY = True
DELETE = False
SELECT_ALL = False

"""
            'C:/Users/gianl/Desktop/Dataset_MOD/fingerspelling5//dataset5/fingerspelling_A',
            'C:/Users/gianl/Desktop/Dataset_MOD/fingerspelling5//dataset5/fingerspelling_B'
            'C:/Users/gianl/Desktop/Dataset_MOD/fingerspelling5//dataset5/fingerspelling_C',
            'C:/Users/gianl/Desktop/Dataset_MOD/fingerspelling5//dataset5/fingerspelling_D',
            'C:/Users/gianl/Desktop/Dataset_MOD/fingerspelling5//dataset5/fingerspelling_E',
            'C:/Users/gianl/Desktop/Dataset_MOD/Dataset ASL Hand Gestures/original_frames',
            'C:/Users/gianl/Desktop/Dataset_MOD/Kaggle_3/kaggle_3_asl_alphabet_train',
            'C:/Users/gianl/Desktop/Dataset_MOD/Kaggle_2/asl_alphabet_train/kaggle_2_asl_alphabet_train',
            'C:/Users/gianl/Desktop/Dataset_MOD/New_Data_1',
            'C:/Users/gianl/Desktop/Dataset_MOD/Video'
            

 
"""


# Copy here all paths to the raw data sets to be used in the program run
# For each data set in the SEL_AMOUNT array the amount of pictures to be selected has to be specified
PATHS = [   'C:/Users/gianl/Desktop/Dataset_MOD/fingerspelling5//dataset5/fingerspelling_A',
            'C:/Users/gianl/Desktop/Dataset_MOD/fingerspelling5//dataset5/fingerspelling_B',
            'C:/Users/gianl/Desktop/Dataset_MOD/fingerspelling5//dataset5/fingerspelling_C',
            'C:/Users/gianl/Desktop/Dataset_MOD/fingerspelling5//dataset5/fingerspelling_D',
            'C:/Users/gianl/Desktop/Dataset_MOD/fingerspelling5//dataset5/fingerspelling_E',
            'C:/Users/gianl/Desktop/Dataset_MOD/Dataset ASL Hand Gestures/original_frames',
            'C:/Users/gianl/Desktop/Dataset_MOD/Kaggle_3/kaggle_3_asl_alphabet_train',
            'C:/Users/gianl/Desktop/Dataset_MOD/Kaggle_2/asl_alphabet_train/kaggle_2_asl_alphabet_train',
            'C:/Users/gianl/Desktop/Dataset_MOD/New_Data_1',
            'C:/Users/gianl/Desktop/Dataset_MOD/Video']



SEL_AMOUNT = [18,18,18,18,18,10,70,40,20,25]


# Select output directory
output_path = filedialog.askdirectory(title="Select output")




for idxP, file_path in enumerate(PATHS):
    print('Input: ' + file_path)
    temp_output = output_path + '/' + os.path.basename(os.path.normpath(file_path+'/'))
    print('Output: ' + temp_output)
    if not os.path.exists(temp_output):
        os.mkdir(temp_output) 
    
    # Get every class available in Input directory (Folder names are used to creat for example A - Z)
    CLASSES = getClasses(file_path)
    
    # Go through every class
    for idxC, folder in enumerate(CLASSES):   
        sub_path = os.path.join(file_path + '/' + folder)
        
        #### Collect all files in directory
        IMAGE_FILES = getImageFiles(sub_path) 
        amount = len(IMAGE_FILES) ## All image files
        print('*****************************************************************')
        print(folder)
        print('Amount of Files: ' + str(amount))  
        print('*****************************************************************')

        #### get List of Files with skeleton in it
        SEL_FILES = scanRawData(IMAGE_FILES,sub_path, delete_img=DELETE) 
        amount_filtered = len(SEL_FILES) ## Files in which a hand was detected
        print(str(amount_filtered) + '/' + str(amount) + ' files with hands detected')
        #print(SEL_FILES)
        #### Select specified amount of files to create dataset and copy them to output
        export_files = createDatasetImages(SEL_FILES, sel_amount=SEL_AMOUNT[idxP],sel_all=SELECT_ALL)            

        print(str(len(export_files)) + ' files selected to copy')
        #print(export_files)
        
        saveDataset(export_files, folder, sub_path, temp_output, annotate_img=ANNOTATE, copy_img=COPY)
            
            
    print('*****************************************************************')
    print('*****************************************************************')
print("Process completed!")
# Out:
# Input: C:/Users/gianl/Desktop/Dataset_MOD/fingerspelling5//dataset5/fingerspelling_A
# Output: C:/Users/gianl/Desktop/out_2/fingerspelling_A
# *****************************************************************
# a
# Amount of Files: 10
# *****************************************************************
# 10/10 files with hands detected
# 10 files selected to copy
# *****************************************************************
# b
# Amount of Files: 126
# *****************************************************************
# 126/126 files with hands detected
# 18 files selected to copy
# *****************************************************************
# c
# Amount of Files: 29
# *****************************************************************
# 29/29 files with hands detected
# 18 files selected to copy
# *****************************************************************
# d
# Amount of Files: 81
# *****************************************************************
# 81/81 files with hands detected
# 18 files selected to copy
# *****************************************************************
# e
# Amount of Files: 42
# *****************************************************************
# 42/42 files with hands detected
# 18 files selected to copy
# *****************************************************************
# f
# Amount of Files: 220
# *****************************************************************
# 220/220 files with hands detected
# 18 files selected to copy
# *****************************************************************
# g
# Amount of Files: 247
# *****************************************************************
# 247/247 files with hands detected
# 18 files selected to copy
# *****************************************************************
# h
# Amount of Files: 366
# *****************************************************************
# 366/366 files with hands detected
# 18 files selected to copy
# *****************************************************************
# i
# Amount of Files: 115
# *****************************************************************
# 115/115 files with hands detected
# 18 files selected to copy
# *****************************************************************
# k
# Amount of Files: 134
# *****************************************************************
# 134/134 files with hands detected
# 18 files selected to copy
# *****************************************************************
# l
# Amount of Files: 222
# *****************************************************************
# 222/222 files with hands detected
# 18 files selected to copy
# *****************************************************************
# m
# Amount of Files: 3
# *****************************************************************
# 3/3 files with hands detected
# 3 files selected to copy
# *****************************************************************
# n
# Amount of Files: 56
# *****************************************************************
# 56/56 files with hands detected
# 18 files selected to copy
# *****************************************************************
# o
# Amount of Files: 6
# *****************************************************************
# 6/6 files with hands detected
# 6 files selected to copy
# *****************************************************************
# p
# Amount of Files: 48
# *****************************************************************
# 48/48 files with hands detected
# 18 files selected to copy
# *****************************************************************
# q
# Amount of Files: 31
# *****************************************************************
# 31/31 files with hands detected
# 18 files selected to copy
# *****************************************************************
# r
# Amount of Files: 60
# *****************************************************************
# 60/60 files with hands detected
# 18 files selected to copy
# *****************************************************************
# s
# Amount of Files: 3
# *****************************************************************
# 3/3 files with hands detected
# 3 files selected to copy
# *****************************************************************
# t
# Amount of Files: 20
# *****************************************************************
# 20/20 files with hands detected
# 18 files selected to copy
# *****************************************************************
# u
# Amount of Files: 22
# *****************************************************************
# 22/22 files with hands detected
# 18 files selected to copy
# *****************************************************************
# v
# Amount of Files: 85
# *****************************************************************
# 85/85 files with hands detected
# 18 files selected to copy
# *****************************************************************
# w
# Amount of Files: 7
# *****************************************************************
# 7/7 files with hands detected
# 7 files selected to copy
# *****************************************************************
# x
# Amount of Files: 172
# *****************************************************************
# 172/172 files with hands detected
# 18 files selected to copy
# *****************************************************************
# y
# Amount of Files: 0
# *****************************************************************
# 0/0 files with hands detected
# 0 files selected to copy
# *****************************************************************
# *****************************************************************
# Input: C:/Users/gianl/Desktop/Dataset_MOD/fingerspelling5//dataset5/fingerspelling_B
# Output: C:/Users/gianl/Desktop/out_2/fingerspelling_B
# *****************************************************************
# a
# Amount of Files: 161
# *****************************************************************
# 161/161 files with hands detected
# 18 files selected to copy
# *****************************************************************
# b
# Amount of Files: 94
# *****************************************************************
# 94/94 files with hands detected
# 18 files selected to copy
# *****************************************************************
# c
# Amount of Files: 299
# *****************************************************************
# 299/299 files with hands detected
# 18 files selected to copy
# *****************************************************************
# d
# Amount of Files: 380
# *****************************************************************
# 380/380 files with hands detected
# 18 files selected to copy
# *****************************************************************
# e
# Amount of Files: 242
# *****************************************************************
# 242/242 files with hands detected
# 18 files selected to copy
# *****************************************************************
# f
# Amount of Files: 332
# *****************************************************************
# 332/332 files with hands detected
# 18 files selected to copy
# *****************************************************************
# g
# Amount of Files: 460
# *****************************************************************
# 460/460 files with hands detected
# 18 files selected to copy
# *****************************************************************
# h
# Amount of Files: 536
# *****************************************************************
# 536/536 files with hands detected
# 18 files selected to copy
# *****************************************************************
# i
# Amount of Files: 300
# *****************************************************************
# 300/300 files with hands detected
# 18 files selected to copy
# *****************************************************************
# k
# Amount of Files: 0
# *****************************************************************
# 0/0 files with hands detected
# 0 files selected to copy
# *****************************************************************
# l
# Amount of Files: 496
# *****************************************************************
# 496/496 files with hands detected
# 18 files selected to copy
# *****************************************************************
# m
# Amount of Files: 304
# *****************************************************************
# 304/304 files with hands detected
# 18 files selected to copy
# *****************************************************************
# n
# Amount of Files: 358
# *****************************************************************
# 358/358 files with hands detected
# 18 files selected to copy
# *****************************************************************
# o
# Amount of Files: 344
# *****************************************************************
# 344/344 files with hands detected
# 18 files selected to copy
# *****************************************************************
# p
# Amount of Files: 127
# *****************************************************************
# 127/127 files with hands detected
# 18 files selected to copy
# *****************************************************************
# q
# Amount of Files: 429
# *****************************************************************
# 429/429 files with hands detected
# 18 files selected to copy
# *****************************************************************
# r
# Amount of Files: 415
# *****************************************************************
# 415/415 files with hands detected
# 18 files selected to copy
# *****************************************************************
# s
# Amount of Files: 516
# *****************************************************************
# 516/516 files with hands detected
# 18 files selected to copy
# *****************************************************************
# t
# Amount of Files: 345
# *****************************************************************
# 345/345 files with hands detected
# 18 files selected to copy
# *****************************************************************
# u
# Amount of Files: 330
# *****************************************************************
# 330/330 files with hands detected
# 18 files selected to copy
# *****************************************************************
# v
# Amount of Files: 462
# *****************************************************************
# 462/462 files with hands detected
# 18 files selected to copy
# *****************************************************************
# w
# Amount of Files: 159
# *****************************************************************
# 159/159 files with hands detected
# 18 files selected to copy
# *****************************************************************
# x
# Amount of Files: 472
# *****************************************************************
# 472/472 files with hands detected
# 18 files selected to copy
# *****************************************************************
# y
# Amount of Files: 360
# *****************************************************************
# 360/360 files with hands detected
# 18 files selected to copy
# *****************************************************************
# *****************************************************************
# Input: C:/Users/gianl/Desktop/Dataset_MOD/fingerspelling5//dataset5/fingerspelling_C
# Output: C:/Users/gianl/Desktop/out_2/fingerspelling_C
# *****************************************************************
# a
# Amount of Files: 42
# *****************************************************************
# 42/42 files with hands detected
# 18 files selected to copy
# *****************************************************************
# b
# Amount of Files: 216
# *****************************************************************
# 216/216 files with hands detected
# 18 files selected to copy
# *****************************************************************
# c
# Amount of Files: 129
# *****************************************************************
# 129/129 files with hands detected
# 18 files selected to copy
# *****************************************************************
# d
# Amount of Files: 359
# *****************************************************************
# 359/359 files with hands detected
# 18 files selected to copy
# *****************************************************************
# e
# Amount of Files: 145
# *****************************************************************
# 145/145 files with hands detected
# 18 files selected to copy
# *****************************************************************
# f
# Amount of Files: 89
# *****************************************************************
# 89/89 files with hands detected
# 18 files selected to copy
# *****************************************************************
# g
# Amount of Files: 506
# *****************************************************************
# 506/506 files with hands detected
# 18 files selected to copy
# *****************************************************************
# h
# Amount of Files: 519
# *****************************************************************
# 519/519 files with hands detected
# 18 files selected to copy
# *****************************************************************
# i
# Amount of Files: 387
# *****************************************************************
# 387/387 files with hands detected
# 18 files selected to copy
# *****************************************************************
# k
# Amount of Files: 246
# *****************************************************************
# 246/246 files with hands detected
# 18 files selected to copy
# *****************************************************************
# l
# Amount of Files: 500
# *****************************************************************
# 500/500 files with hands detected
# 18 files selected to copy
# *****************************************************************
# m
# Amount of Files: 330
# *****************************************************************
# 330/330 files with hands detected
# 18 files selected to copy
# *****************************************************************
# n
# Amount of Files: 373
# *****************************************************************
# 373/373 files with hands detected
# 18 files selected to copy
# *****************************************************************
# o
# Amount of Files: 122
# *****************************************************************
# 122/122 files with hands detected
# 18 files selected to copy
# *****************************************************************
# p
# Amount of Files: 39
# *****************************************************************
# 39/39 files with hands detected
# 18 files selected to copy
# *****************************************************************
# q
# Amount of Files: 212
# *****************************************************************
# 212/212 files with hands detected
# 18 files selected to copy
# *****************************************************************
# r
# Amount of Files: 370
# *****************************************************************
# 370/370 files with hands detected
# 18 files selected to copy
# *****************************************************************
# s
# Amount of Files: 94
# *****************************************************************
# 94/94 files with hands detected
# 18 files selected to copy
# *****************************************************************
# t
# Amount of Files: 274
# *****************************************************************
# 274/274 files with hands detected
# 18 files selected to copy
# *****************************************************************
# u
# Amount of Files: 325
# *****************************************************************
# 325/325 files with hands detected
# 18 files selected to copy
# *****************************************************************
# v
# Amount of Files: 316
# *****************************************************************
# 316/316 files with hands detected
# 18 files selected to copy
# *****************************************************************
# w
# Amount of Files: 270
# *****************************************************************
# 270/270 files with hands detected
# 18 files selected to copy
# *****************************************************************
# x
# Amount of Files: 502
# *****************************************************************
# 502/502 files with hands detected
# 18 files selected to copy
# *****************************************************************
# y
# Amount of Files: 384
# *****************************************************************
# 384/384 files with hands detected
# 18 files selected to copy
# *****************************************************************
# *****************************************************************
# Input: C:/Users/gianl/Desktop/Dataset_MOD/fingerspelling5//dataset5/fingerspelling_D
# Output: C:/Users/gianl/Desktop/out_2/fingerspelling_D
# *****************************************************************
# a
# Amount of Files: 68
# *****************************************************************
# 68/68 files with hands detected
# 18 files selected to copy
# *****************************************************************
# b
# Amount of Files: 7
# *****************************************************************
# 7/7 files with hands detected
# 7 files selected to copy
# *****************************************************************
# c
# Amount of Files: 257
# *****************************************************************
# 257/257 files with hands detected
# 18 files selected to copy
# *****************************************************************
# d
# Amount of Files: 308
# *****************************************************************
# 308/308 files with hands detected
# 18 files selected to copy
# *****************************************************************
# e
# Amount of Files: 109
# *****************************************************************
# 109/109 files with hands detected
# 18 files selected to copy
# *****************************************************************
# f
# Amount of Files: 233
# *****************************************************************
# 233/233 files with hands detected
# 18 files selected to copy
# *****************************************************************
# g
# Amount of Files: 341
# *****************************************************************
# 341/341 files with hands detected
# 18 files selected to copy
# *****************************************************************
# h
# Amount of Files: 287
# *****************************************************************
# 287/287 files with hands detected
# 18 files selected to copy
# *****************************************************************
# i
# Amount of Files: 152
# *****************************************************************
# 152/152 files with hands detected
# 18 files selected to copy
# *****************************************************************
# k
# Amount of Files: 182
# *****************************************************************
# 182/182 files with hands detected
# 18 files selected to copy
# *****************************************************************
# l
# Amount of Files: 443
# *****************************************************************
# 443/443 files with hands detected
# 18 files selected to copy
# *****************************************************************
# m
# Amount of Files: 90
# *****************************************************************
# 90/90 files with hands detected
# 18 files selected to copy
# *****************************************************************
# n
# Amount of Files: 303
# *****************************************************************
# 303/303 files with hands detected
# 18 files selected to copy
# *****************************************************************
# o
# Amount of Files: 123
# *****************************************************************
# 123/123 files with hands detected
# 18 files selected to copy
# *****************************************************************
# p
# Amount of Files: 0
# *****************************************************************
# 0/0 files with hands detected
# 0 files selected to copy
# *****************************************************************
# q
# Amount of Files: 1
# *****************************************************************
# 1/1 files with hands detected
# 1 files selected to copy
# *****************************************************************
# r
# Amount of Files: 219
# *****************************************************************
# 219/219 files with hands detected
# 18 files selected to copy
# *****************************************************************
# s
# Amount of Files: 49
# *****************************************************************
# 49/49 files with hands detected
# 18 files selected to copy
# *****************************************************************
# t
# Amount of Files: 126
# *****************************************************************
# 126/126 files with hands detected
# 18 files selected to copy
# *****************************************************************
# u
# Amount of Files: 54
# *****************************************************************
# 54/54 files with hands detected
# 18 files selected to copy
# *****************************************************************
# v
# Amount of Files: 293
# *****************************************************************
# 293/293 files with hands detected
# 18 files selected to copy
# *****************************************************************
# w
# Amount of Files: 6
# *****************************************************************
# 6/6 files with hands detected
# 6 files selected to copy
# *****************************************************************
# x
# Amount of Files: 32
# *****************************************************************
# 32/32 files with hands detected
# 18 files selected to copy
# *****************************************************************
# y
# Amount of Files: 59
# *****************************************************************
# 59/59 files with hands detected
# 18 files selected to copy
# *****************************************************************
# *****************************************************************
# Input: C:/Users/gianl/Desktop/Dataset_MOD/fingerspelling5//dataset5/fingerspelling_E
# Output: C:/Users/gianl/Desktop/out_2/fingerspelling_E
# *****************************************************************
# a
# Amount of Files: 120
# *****************************************************************
# 120/120 files with hands detected
# 18 files selected to copy
# *****************************************************************
# b
# Amount of Files: 8
# *****************************************************************
# 8/8 files with hands detected
# 8 files selected to copy
# *****************************************************************
# c
# Amount of Files: 359
# *****************************************************************
# 359/359 files with hands detected
# 18 files selected to copy
# *****************************************************************
# d
# Amount of Files: 408
# *****************************************************************
# 408/408 files with hands detected
# 18 files selected to copy
# *****************************************************************
# e
# Amount of Files: 230
# *****************************************************************
# 230/230 files with hands detected
# 18 files selected to copy
# *****************************************************************
# f
# Amount of Files: 501
# *****************************************************************
# 501/501 files with hands detected
# 18 files selected to copy
# *****************************************************************
# g
# Amount of Files: 527
# *****************************************************************
# 527/527 files with hands detected
# 18 files selected to copy
# *****************************************************************
# h
# Amount of Files: 534
# *****************************************************************
# 534/534 files with hands detected
# 18 files selected to copy
# *****************************************************************
# i
# Amount of Files: 525
# *****************************************************************
# 525/525 files with hands detected
# 18 files selected to copy
# *****************************************************************
# k
# Amount of Files: 352
# *****************************************************************
# 352/352 files with hands detected
# 18 files selected to copy
# *****************************************************************
# l
# Amount of Files: 451
# *****************************************************************
# 451/451 files with hands detected
# 18 files selected to copy
# *****************************************************************
# m
# Amount of Files: 254
# *****************************************************************
# 254/254 files with hands detected
# 18 files selected to copy
# *****************************************************************
# n
# Amount of Files: 278
# *****************************************************************
# 278/278 files with hands detected
# 18 files selected to copy
# *****************************************************************
# o
# Amount of Files: 139
# *****************************************************************
# 139/139 files with hands detected
# 18 files selected to copy
# *****************************************************************
# p
# Amount of Files: 193
# *****************************************************************
# 193/193 files with hands detected
# 18 files selected to copy
# *****************************************************************
# q
# Amount of Files: 107
# *****************************************************************
# 107/107 files with hands detected
# 18 files selected to copy
# *****************************************************************
# r
# Amount of Files: 293
# *****************************************************************
# 293/293 files with hands detected
# 18 files selected to copy
# *****************************************************************
# s
# Amount of Files: 120
# *****************************************************************
# 120/120 files with hands detected
# 18 files selected to copy
# *****************************************************************
# t
# Amount of Files: 120
# *****************************************************************
# 120/120 files with hands detected
# 18 files selected to copy
# *****************************************************************
# u
# Amount of Files: 64
# *****************************************************************
# 64/64 files with hands detected
# 18 files selected to copy
# *****************************************************************
# v
# Amount of Files: 316
# *****************************************************************
# 316/316 files with hands detected
# 18 files selected to copy
# *****************************************************************
# w
# Amount of Files: 111
# *****************************************************************
# 111/111 files with hands detected
# 18 files selected to copy
# *****************************************************************
# x
# Amount of Files: 487
# *****************************************************************
# 487/487 files with hands detected
# 18 files selected to copy
# *****************************************************************
# y
# Amount of Files: 291
# *****************************************************************
# 291/291 files with hands detected
# 18 files selected to copy
# *****************************************************************
# *****************************************************************
# Input: C:/Users/gianl/Desktop/Dataset_MOD/Dataset ASL Hand Gestures/original_frames
# Output: C:/Users/gianl/Desktop/out_2/original_frames
# *****************************************************************
# A
# Amount of Files: 18
# *****************************************************************
# 18/18 files with hands detected
# 10 files selected to copy
# *****************************************************************
# B
# Amount of Files: 35
# *****************************************************************
# 35/35 files with hands detected
# 10 files selected to copy
# *****************************************************************
# C
# Amount of Files: 33
# *****************************************************************
# 33/33 files with hands detected
# 10 files selected to copy
# *****************************************************************
# D
# Amount of Files: 40
# *****************************************************************
# 40/40 files with hands detected
# 10 files selected to copy
# *****************************************************************
# E
# Amount of Files: 23
# *****************************************************************
# 23/23 files with hands detected
# 10 files selected to copy
# *****************************************************************
# F
# Amount of Files: 38
# *****************************************************************
# 38/38 files with hands detected
# 10 files selected to copy
# *****************************************************************
# G
# Amount of Files: 32
# *****************************************************************
# 32/32 files with hands detected
# 10 files selected to copy
# *****************************************************************
# H
# Amount of Files: 31
# *****************************************************************
# 31/31 files with hands detected
# 10 files selected to copy
# *****************************************************************
# I
# Amount of Files: 36
# *****************************************************************
# 36/36 files with hands detected
# 10 files selected to copy
# *****************************************************************
# K
# Amount of Files: 39
# *****************************************************************
# 39/39 files with hands detected
# 10 files selected to copy
# *****************************************************************
# L
# Amount of Files: 31
# *****************************************************************
# 31/31 files with hands detected
# 10 files selected to copy
# *****************************************************************
# M
# Amount of Files: 27
# *****************************************************************
# 27/27 files with hands detected
# 10 files selected to copy
# *****************************************************************
# N
# Amount of Files: 28
# *****************************************************************
# 28/28 files with hands detected
# 10 files selected to copy
# *****************************************************************
# O
# Amount of Files: 30
# *****************************************************************
# 30/30 files with hands detected
# 10 files selected to copy
# *****************************************************************
# P
# Amount of Files: 6
# *****************************************************************
# 6/6 files with hands detected
# 6 files selected to copy
# *****************************************************************
# Q
# Amount of Files: 16
# *****************************************************************
# 16/16 files with hands detected
# 10 files selected to copy
# *****************************************************************
# R
# Amount of Files: 25
# *****************************************************************
# 25/25 files with hands detected
# 10 files selected to copy
# *****************************************************************
# S
# Amount of Files: 20
# *****************************************************************
# 20/20 files with hands detected
# 10 files selected to copy
# *****************************************************************
# T
# Amount of Files: 26
# *****************************************************************
# 26/26 files with hands detected
# 10 files selected to copy
# *****************************************************************
# U
# Amount of Files: 30
# *****************************************************************
# 30/30 files with hands detected
# 10 files selected to copy
# *****************************************************************
# V
# Amount of Files: 40
# *****************************************************************
# 40/40 files with hands detected
# 10 files selected to copy
# *****************************************************************
# W
# Amount of Files: 40
# *****************************************************************
# 40/40 files with hands detected
# 10 files selected to copy
# *****************************************************************
# X
# Amount of Files: 13
# *****************************************************************
# 13/13 files with hands detected
# 10 files selected to copy
# *****************************************************************
# Y
# Amount of Files: 38
# *****************************************************************
# 38/38 files with hands detected
# 10 files selected to copy
# *****************************************************************
# *****************************************************************
# Input: C:/Users/gianl/Desktop/Dataset_MOD/Kaggle_3/kaggle_3_asl_alphabet_train
# Output: C:/Users/gianl/Desktop/out_2/kaggle_3_asl_alphabet_train
# *****************************************************************
# A
# Amount of Files: 501
# *****************************************************************
# 501/501 files with hands detected
# 70 files selected to copy
# *****************************************************************
# B
# Amount of Files: 744
# *****************************************************************
# 744/744 files with hands detected
# 70 files selected to copy
# *****************************************************************
# C
# Amount of Files: 406
# *****************************************************************
# 406/406 files with hands detected
# 70 files selected to copy
# *****************************************************************
# D
# Amount of Files: 332
# *****************************************************************
# 332/332 files with hands detected
# 70 files selected to copy
# *****************************************************************
# E
# Amount of Files: 512
# *****************************************************************
# 512/512 files with hands detected
# 70 files selected to copy
# *****************************************************************
# F
# Amount of Files: 791
# *****************************************************************
# 791/791 files with hands detected
# 70 files selected to copy
# *****************************************************************
# G
# Amount of Files: 510
# *****************************************************************
# 510/510 files with hands detected
# 70 files selected to copy
# *****************************************************************
# H
# Amount of Files: 445
# *****************************************************************
# 445/445 files with hands detected
# 70 files selected to copy
# *****************************************************************
# I
# Amount of Files: 421
# *****************************************************************
# 421/421 files with hands detected
# 70 files selected to copy
# *****************************************************************
# K
# Amount of Files: 378
# *****************************************************************
# 378/378 files with hands detected
# 70 files selected to copy
# *****************************************************************
# L
# Amount of Files: 648
# *****************************************************************
# 648/648 files with hands detected
# 70 files selected to copy
# *****************************************************************
# M
# Amount of Files: 219
# *****************************************************************
# 219/219 files with hands detected
# 70 files selected to copy
# *****************************************************************
# N
# Amount of Files: 230
# *****************************************************************
# 230/230 files with hands detected
# 70 files selected to copy
# *****************************************************************
# O
# Amount of Files: 389
# *****************************************************************
# 389/389 files with hands detected
# 70 files selected to copy
# *****************************************************************
# P
# Amount of Files: 62
# *****************************************************************
# 62/62 files with hands detected
# 62 files selected to copy
# *****************************************************************
# Q
# Amount of Files: 253
# *****************************************************************
# 253/253 files with hands detected
# 70 files selected to copy
# *****************************************************************
# R
# Amount of Files: 348
# *****************************************************************
# 348/348 files with hands detected
# 70 files selected to copy
# *****************************************************************
# S
# Amount of Files: 330
# *****************************************************************
# 330/330 files with hands detected
# 70 files selected to copy
# *****************************************************************
# T
# Amount of Files: 226
# *****************************************************************
# 226/226 files with hands detected
# 70 files selected to copy
# *****************************************************************
# U
# Amount of Files: 332
# *****************************************************************
# 332/332 files with hands detected
# 70 files selected to copy
# *****************************************************************
# V
# Amount of Files: 401
# *****************************************************************
# 401/401 files with hands detected
# 70 files selected to copy
# *****************************************************************
# W
# Amount of Files: 488
# *****************************************************************
# 488/488 files with hands detected
# 70 files selected to copy
# *****************************************************************
# X
# Amount of Files: 327
# *****************************************************************
# 327/327 files with hands detected
# 70 files selected to copy
# *****************************************************************
# Y
# Amount of Files: 428
# *****************************************************************
# 428/428 files with hands detected
# 70 files selected to copy
# *****************************************************************
# *****************************************************************
# Input: C:/Users/gianl/Desktop/Dataset_MOD/Kaggle_2/asl_alphabet_train/kaggle_2_asl_alphabet_train
# Output: C:/Users/gianl/Desktop/out_2/kaggle_2_asl_alphabet_train
# *****************************************************************
# A
# Amount of Files: 1771
# *****************************************************************
# 1771/1771 files with hands detected
# 40 files selected to copy
# *****************************************************************
# B
# Amount of Files: 1971
# *****************************************************************
# 1971/1971 files with hands detected
# 40 files selected to copy
# *****************************************************************
# C
# Amount of Files: 1361
# *****************************************************************
# 1361/1361 files with hands detected
# 40 files selected to copy
# *****************************************************************
# D
# Amount of Files: 1555
# *****************************************************************
# 1555/1555 files with hands detected
# 40 files selected to copy
# *****************************************************************
# E
# Amount of Files: 1661
# *****************************************************************
# 1661/1661 files with hands detected
# 40 files selected to copy
# *****************************************************************
# F
# Amount of Files: 2326
# *****************************************************************
# 2326/2326 files with hands detected
# 40 files selected to copy
# *****************************************************************
# G
# Amount of Files: 1949
# *****************************************************************
# 1949/1949 files with hands detected
# 40 files selected to copy
# *****************************************************************
# H
# Amount of Files: 1184
# *****************************************************************
# 1184/1184 files with hands detected
# 40 files selected to copy
# *****************************************************************
# I
# Amount of Files: 1970
# *****************************************************************
# 1970/1970 files with hands detected
# 40 files selected to copy
# *****************************************************************
# L
# Amount of Files: 2027
# *****************************************************************
# 2027/2027 files with hands detected
# 40 files selected to copy
# *****************************************************************
# N
# Amount of Files: 35
# *****************************************************************
# 35/35 files with hands detected
# 35 files selected to copy
# *****************************************************************
# O
# Amount of Files: 1578
# *****************************************************************
# 1578/1578 files with hands detected
# 40 files selected to copy
# *****************************************************************
# Q
# Amount of Files: 1027
# *****************************************************************
# 1027/1027 files with hands detected
# 40 files selected to copy
# *****************************************************************
# R
# Amount of Files: 1807
# *****************************************************************
# 1807/1807 files with hands detected
# 40 files selected to copy
# *****************************************************************
# S
# Amount of Files: 1888
# *****************************************************************
# 1888/1888 files with hands detected
# 40 files selected to copy
# *****************************************************************
# U
# Amount of Files: 2271
# *****************************************************************
# 2271/2271 files with hands detected
# 40 files selected to copy
# *****************************************************************
# V
# Amount of Files: 2335
# *****************************************************************
# 2335/2335 files with hands detected
# 40 files selected to copy
# *****************************************************************
# W
# Amount of Files: 2195
# *****************************************************************
# 2195/2195 files with hands detected
# 40 files selected to copy
# *****************************************************************
# X
# Amount of Files: 1810
# *****************************************************************
# 1810/1810 files with hands detected
# 40 files selected to copy
# *****************************************************************
# Y
# Amount of Files: 2214
# *****************************************************************
# 2214/2214 files with hands detected
# 40 files selected to copy
# *****************************************************************
# *****************************************************************
# Input: C:/Users/gianl/Desktop/Dataset_MOD/New_Data_1
# Output: C:/Users/gianl/Desktop/out_2/New_Data_1
# *****************************************************************
# A
# Amount of Files: 28
# *****************************************************************
# 28/28 files with hands detected
# 20 files selected to copy
# *****************************************************************
# B
# Amount of Files: 26
# *****************************************************************
# 26/26 files with hands detected
# 20 files selected to copy
# *****************************************************************
# C
# Amount of Files: 22
# *****************************************************************
# 22/22 files with hands detected
# 20 files selected to copy
# *****************************************************************
# D
# Amount of Files: 25
# *****************************************************************
# 25/25 files with hands detected
# 20 files selected to copy
# *****************************************************************
# E
# Amount of Files: 28
# *****************************************************************
# 28/28 files with hands detected
# 20 files selected to copy
# *****************************************************************
# F
# Amount of Files: 30
# *****************************************************************
# 30/30 files with hands detected
# 20 files selected to copy
# *****************************************************************
# G
# Amount of Files: 27
# *****************************************************************
# 27/27 files with hands detected
# 20 files selected to copy
# *****************************************************************
# H
# Amount of Files: 30
# *****************************************************************
# 30/30 files with hands detected
# 20 files selected to copy
# *****************************************************************
# I
# Amount of Files: 14
# *****************************************************************
# 14/14 files with hands detected
# 14 files selected to copy
# *****************************************************************
# K
# Amount of Files: 24
# *****************************************************************
# 24/24 files with hands detected
# 20 files selected to copy
# *****************************************************************
# L
# Amount of Files: 28
# *****************************************************************
# 28/28 files with hands detected
# 20 files selected to copy
# *****************************************************************
# N
# Amount of Files: 14
# *****************************************************************
# 14/14 files with hands detected
# 14 files selected to copy
# *****************************************************************
# O
# Amount of Files: 22
# *****************************************************************
# 22/22 files with hands detected
# 20 files selected to copy
# *****************************************************************
# Q
# Amount of Files: 25
# *****************************************************************
# 25/25 files with hands detected
# 20 files selected to copy
# *****************************************************************
# R
# Amount of Files: 30
# *****************************************************************
# 30/30 files with hands detected
# 20 files selected to copy
# *****************************************************************
# S
# Amount of Files: 25
# *****************************************************************
# 25/25 files with hands detected
# 20 files selected to copy
# *****************************************************************
# U
# Amount of Files: 26
# *****************************************************************
# 26/26 files with hands detected
# 20 files selected to copy
# *****************************************************************
# V
# Amount of Files: 28
# *****************************************************************
# 28/28 files with hands detected
# 20 files selected to copy
# *****************************************************************
# W
# Amount of Files: 29
# *****************************************************************
# 29/29 files with hands detected
# 20 files selected to copy
# *****************************************************************
# X
# Amount of Files: 30
# *****************************************************************
# 30/30 files with hands detected
# 20 files selected to copy
# *****************************************************************
# Y
# Amount of Files: 29
# *****************************************************************
# 29/29 files with hands detected
# 20 files selected to copy
# *****************************************************************
# *****************************************************************
# Input: C:/Users/gianl/Desktop/Dataset_MOD/Video
# Output: C:/Users/gianl/Desktop/out_2/Video
# *****************************************************************
# A
# Amount of Files: 20
# *****************************************************************
# 20/20 files with hands detected
# 20 files selected to copy
# *****************************************************************
# B
# Amount of Files: 19
# *****************************************************************
# 19/19 files with hands detected
# 19 files selected to copy
# *****************************************************************
# C
# Amount of Files: 21
# *****************************************************************
# 21/21 files with hands detected
# 21 files selected to copy
# *****************************************************************
# D
# Amount of Files: 22
# *****************************************************************
# 22/22 files with hands detected
# 22 files selected to copy
# *****************************************************************
# E
# Amount of Files: 21
# *****************************************************************
# 21/21 files with hands detected
# 21 files selected to copy
# *****************************************************************
# F
# Amount of Files: 20
# *****************************************************************
# 20/20 files with hands detected
# 20 files selected to copy
# *****************************************************************
# G
# Amount of Files: 18
# *****************************************************************
# 18/18 files with hands detected
# 18 files selected to copy
# *****************************************************************
# H
# Amount of Files: 19
# *****************************************************************
# 19/19 files with hands detected
# 19 files selected to copy
# *****************************************************************
# I
# Amount of Files: 14
# *****************************************************************
# 14/14 files with hands detected
# 14 files selected to copy
# *****************************************************************
# K
# Amount of Files: 21
# *****************************************************************
# 21/21 files with hands detected
# 21 files selected to copy
# *****************************************************************
# L
# Amount of Files: 21
# *****************************************************************
# 21/21 files with hands detected
# 21 files selected to copy
# *****************************************************************
# M
# Amount of Files: 20
# *****************************************************************
# 20/20 files with hands detected
# 20 files selected to copy
# *****************************************************************
# N
# Amount of Files: 19
# *****************************************************************
# 19/19 files with hands detected
# 19 files selected to copy
# *****************************************************************
# O
# Amount of Files: 20
# *****************************************************************
# 20/20 files with hands detected
# 20 files selected to copy
# *****************************************************************
# P
# Amount of Files: 11
# *****************************************************************
# 11/11 files with hands detected
# 11 files selected to copy
# *****************************************************************
# Q
# Amount of Files: 15
# *****************************************************************
# 15/15 files with hands detected
# 15 files selected to copy
# *****************************************************************
# R
# Amount of Files: 17
# *****************************************************************
# 17/17 files with hands detected
# 17 files selected to copy
# *****************************************************************
# S
# Amount of Files: 20
# *****************************************************************
# 20/20 files with hands detected
# 20 files selected to copy
# *****************************************************************
# T
# Amount of Files: 20
# *****************************************************************
# 20/20 files with hands detected
# 20 files selected to copy
# *****************************************************************
# U
# Amount of Files: 20
# *****************************************************************
# 20/20 files with hands detected
# 20 files selected to copy
# *****************************************************************
# V
# Amount of Files: 20
# *****************************************************************
# 20/20 files with hands detected
# 20 files selected to copy
# *****************************************************************
# W
# Amount of Files: 20
# *****************************************************************
# 20/20 files with hands detected
# 20 files selected to copy
# *****************************************************************
# X
# Amount of Files: 22
# *****************************************************************
# 22/22 files with hands detected
# 22 files selected to copy
# *****************************************************************
# Y
# Amount of Files: 22
# *****************************************************************
# 22/22 files with hands detected
# 22 files selected to copy
# *****************************************************************
# *****************************************************************
# Process completed!

# %%
### to .csv
